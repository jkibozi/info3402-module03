# %% [markdown]
# # INFO 3402 - Module Assignment 3
# [Jason Kibozi-Yocka](https://github.com/jkibozi)<br>
# University of Colorado Boulder<br>

# %%
# Libraries for working with APIs
import requests as req
import json

# Libraries for parsing HTML
from bs4 import BeautifulSoup as bs

# Libraries for dataframes
import numpy as np
import pandas as pd
pd.options.display.max_columns = 200

# Libraries for sentiment analysis
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer as vsia

# Libraries for data visualization
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# In order to use/import vader: `pip install vaderSentiment`

# %% [markdown]
# ## API #1: [Billboard Top 100](https://github.com/guoguo12/billboard-charts)
# `pip install billboard.py`<br>
# [billboard.py documentation](https://github.com/guoguo12/billboard-charts)

# %%
# libraries for working with billboard api
import billboard as bb

# %%
# retrieve billboard hot 100 data
hot100 = bb.ChartData('hot-100')

# %%
# let's see what type of object this is
type(hot100)
# Out:
# billboard.ChartData

# %%
# pandas can't convert this datatype to a dataframe so...
# let's turn it into a list of lists
billList = []
for i in range(100):
    song = hot100[i]
    entry = [song.title,song.artist,song.weeks]
    billList.append(entry)

# %%
# let's check out our list
billList
# Out:
# [['HIGHEST IN THE ROOM', 'Travis Scott', 1],
#  ['Truth Hurts', 'Lizzo', 23],
#  ['Senorita', 'Shawn Mendes & Camila Cabello', 16],
#  ['10,000 Hours', 'Dan + Shay & Justin Bieber', 1],
#  ['Someone You Loved', 'Lewis Capaldi', 22],
#  ['Circles', 'Post Malone', 6],
#  ['No Guidance', 'Chris Brown Featuring Drake', 18],
#  ['Ran$om', 'Lil Tecca', 19],
#  ['Bad Guy', 'Billie Eilish', 28],
#  ['Panini', 'Lil Nas X', 16],
#  ['Bandit', 'Juice WRLD & YoungBoy Never Broke Again', 1],
#  ['Goodbyes', 'Post Malone Featuring Young Thug', 14],
#  ["I Don't Care", 'Ed Sheeran & Justin Bieber', 22],
#  ['Old Town Road', 'Lil Nas X Featuring Billy Ray Cyrus', 32],
#  ['Beautiful People', 'Ed Sheeran Featuring Khalid', 15],
#  ['Playing Games', 'Summer Walker', 6],
#  ['Talk', 'Khalid', 35],
#  ['Sunflower (Spider-Man: Into The Spider-Verse)',
#   'Post Malone & Swae Lee',
#   51],
#  ['Sucker', 'Jonas Brothers', 32],
#  ['Memories', 'Maroon 5', 3],
#  ['Money In The Grave', 'Drake Featuring Rick Ross', 17],
#  ['Trampoline', 'SHAED', 19],
#  ['Only Human', 'Jonas Brothers', 17],
#  ['Good As Hell', 'Lizzo', 7],
#  ['Suge', 'DaBaby', 28],
#  ['How Do You Sleep?', 'Sam Smith', 12],
#  ['On Chill', 'Wale Featuring Jeremih', 9],
#  ['You Need To Calm Down', 'Taylor Swift', 17],
#  ['Baby', 'Lil Baby & DaBaby', 12],
#  ["Ballin'", 'Mustard Featuring Roddy Ricch', 12],
#  ['Hot Girl Summer', 'Megan Thee Stallion, Nicki Minaj & Ty Dolla $ign', 9],
#  ['INTRO', 'DaBaby', 3],
#  ['Dancing With A Stranger', 'Sam Smith & Normani', 39],
#  ['Lover', 'Taylor Swift', 8],
#  ['My Type', 'Saweetie', 15],
#  ['Prayed For You', 'Matt Stell', 10],
#  ["223's", 'YNW Melly & 9lokknine', 5],
#  ['Hot', 'Young Thug Featuring Gunna', 8],
#  ['Wow.', 'Post Malone', 42],
#  ['Camelot', 'NLE Choppa', 4],
#  ['BOP', 'DaBaby', 2],
#  ['Come Thru', 'Summer Walker & Usher', 1],
#  ['One Thing Right', 'Marshmello & Kane Brown', 16],
#  ['Graveyard', 'Halsey', 4],
#  ['The Git Up', 'Blanco Brown', 18],
#  ['VIBEZ', 'DaBaby', 2],
#  ['Heat', 'Chris Brown Featuring Gunna', 6],
#  ["If I Can't Have You", 'Shawn Mendes', 23],
#  ["Even Though I'm Leaving", 'Luke Combs', 6],
#  ['Take What You Want',
#   'Post Malone Featuring Ozzy Osbourne & Travis Scott',
#   5],
#  ["I Don't Know About You", 'Chris Lane', 14],
#  ['Time', 'NF', 12],
#  ['The Bones', 'Maren Morris', 3],
#  ['One Man Band', 'Old Dominion', 7],
#  ['Cash Shit', 'Megan Thee Stallion Featuring DaBaby', 16],
#  ['Good Vibes', 'Chris Janson', 6],
#  ['The London', 'Young Thug, J. Cole & Travis Scott', 20],
#  ['Liar', 'Camila Cabello', 5],
#  ['Boyfriend', 'Ariana Grande & Social House', 10],
#  ['Living', 'Dierks Bentley', 11],
#  ["I'll Kill You", 'Summer Walker Featuring Jhene Aiko', 1],
#  ['Enemies', 'Post Malone Featuring DaBaby', 5],
#  ['Love You Too Late', 'Cole Swindell', 10],
#  ['What Happens In A Small Town', 'Brantley Gilbert + Lindsay Ell', 9],
#  ['Motivation', 'Normani', 8],
#  ['Hot Girl Bummer', 'blackbear', 4],
#  ['TOES', 'DaBaby Featuring Lil Baby & Moneybagg Yo', 2],
#  ['Stretch You Out', 'Summer Walker Featuring A Boogie Wit da Hoodie', 1],
#  ['Every Little Thing', 'Russell Dickerson', 6],
#  ['China', 'Anuel AA, Daddy Yankee, Karol G, Ozuna & J Balvin', 12],
#  ['Baby Sitter', 'DaBaby Featuring Offset', 9],
#  ['Lalala', 'Y2K & bbno$', 15],
#  ['Body', 'Summer Walker', 1],
#  ['Writing On The Wall',
#   'French Montana Featuring Post Malone, Cardi B & Rvssian',
#   2],
#  ["Don't Call Me Angel (Charlie's Angels)",
#   'Ariana Grande, Miley Cyrus & Lana Del Rey',
#   4],
#  ['Saint-Tropez', 'Post Malone', 5],
#  ['Tip Of My Tongue', 'Kenny Chesney', 13],
#  ['Otro Trago', 'Sech, Darell, Nicky Jam, Ozuna & Anuel AA', 18],
#  ['Drunk Dialing...LODT', 'Summer Walker', 1],
#  ['Over It', 'Summer Walker', 1],
#  ["Hollywood's Bleeding", 'Post Malone', 5],
#  ['Remember You Young', 'Thomas Rhett', 4],
#  ['Nice To Meet Ya', 'Niall Horan', 1],
#  ['F.N', 'Lil Tjay', 9],
#  ['Higher Love', 'Kygo X Whitney Houston', 5],
#  ['Wish Wish', 'DJ Khaled Featuring Cardi B & 21 Savage', 13],
#  ['Callaita', 'Bad Bunny & Tainy', 18],
#  ['Southbound', 'Carrie Underwood', 13],
#  ['Bad Bad Bad', 'Young Thug Featuring Lil Baby', 8],
#  ['RAW SHIT', 'DaBaby Featuring Migos', 2],
#  ['Leave Em Alone', 'Layton Greene, Lil Baby, City Girls & PnB Rock', 1],
#  ['Potential', 'Summer Walker', 1],
#  ['Right Back', 'Khalid Featuring A Boogie Wit da Hoodie', 11],
#  ['Die For Me', 'Post Malone Featuring Future & Halsey', 5],
#  ['Heartache Medication', 'Jon Pardi', 2],
#  ['Dance Monkey', 'Tones And I', 1],
#  ['POP STAR', 'DaBaby Featuring Kevin Gates', 2],
#  ['Self Control', 'YoungBoy Never Broke Again', 5],
#  ['No Me Conoce', 'Jhay Cortez, J Balvin & Bad Bunny', 14],
#  ['Slow Dancing In The Dark', 'Joji', 2]]

# %%
# let's break down the artists even further by seperating them with ';'
for i in range(100):
    song = billList[i]
    artists = song[1]
    if 'Featuring' in artists:
        artists = artists.replace(' Featuring ',';')
    if '&' in artists:
        artists = artists.replace(' & ',';')
    if ',' in artists:
        artists = artists.replace(', ',';')
    if '+' in artists:
        artists = artists.replace(' + ',';')
    billList[i][1] = artists

# %%
# let's check out our list
billList
# Out:
# [['HIGHEST IN THE ROOM', 'Travis Scott', 1],
#  ['Truth Hurts', 'Lizzo', 23],
#  ['Senorita', 'Shawn Mendes;Camila Cabello', 16],
#  ['10,000 Hours', 'Dan;Shay;Justin Bieber', 1],
#  ['Someone You Loved', 'Lewis Capaldi', 22],
#  ['Circles', 'Post Malone', 6],
#  ['No Guidance', 'Chris Brown;Drake', 18],
#  ['Ran$om', 'Lil Tecca', 19],
#  ['Bad Guy', 'Billie Eilish', 28],
#  ['Panini', 'Lil Nas X', 16],
#  ['Bandit', 'Juice WRLD;YoungBoy Never Broke Again', 1],
#  ['Goodbyes', 'Post Malone;Young Thug', 14],
#  ["I Don't Care", 'Ed Sheeran;Justin Bieber', 22],
#  ['Old Town Road', 'Lil Nas X;Billy Ray Cyrus', 32],
#  ['Beautiful People', 'Ed Sheeran;Khalid', 15],
#  ['Playing Games', 'Summer Walker', 6],
#  ['Talk', 'Khalid', 35],
#  ['Sunflower (Spider-Man: Into The Spider-Verse)', 'Post Malone;Swae Lee', 51],
#  ['Sucker', 'Jonas Brothers', 32],
#  ['Memories', 'Maroon 5', 3],
#  ['Money In The Grave', 'Drake;Rick Ross', 17],
#  ['Trampoline', 'SHAED', 19],
#  ['Only Human', 'Jonas Brothers', 17],
#  ['Good As Hell', 'Lizzo', 7],
#  ['Suge', 'DaBaby', 28],
#  ['How Do You Sleep?', 'Sam Smith', 12],
#  ['On Chill', 'Wale;Jeremih', 9],
#  ['You Need To Calm Down', 'Taylor Swift', 17],
#  ['Baby', 'Lil Baby;DaBaby', 12],
#  ["Ballin'", 'Mustard;Roddy Ricch', 12],
#  ['Hot Girl Summer', 'Megan Thee Stallion;Nicki Minaj;Ty Dolla $ign', 9],
#  ['INTRO', 'DaBaby', 3],
#  ['Dancing With A Stranger', 'Sam Smith;Normani', 39],
#  ['Lover', 'Taylor Swift', 8],
#  ['My Type', 'Saweetie', 15],
#  ['Prayed For You', 'Matt Stell', 10],
#  ["223's", 'YNW Melly;9lokknine', 5],
#  ['Hot', 'Young Thug;Gunna', 8],
#  ['Wow.', 'Post Malone', 42],
#  ['Camelot', 'NLE Choppa', 4],
#  ['BOP', 'DaBaby', 2],
#  ['Come Thru', 'Summer Walker;Usher', 1],
#  ['One Thing Right', 'Marshmello;Kane Brown', 16],
#  ['Graveyard', 'Halsey', 4],
#  ['The Git Up', 'Blanco Brown', 18],
#  ['VIBEZ', 'DaBaby', 2],
#  ['Heat', 'Chris Brown;Gunna', 6],
#  ["If I Can't Have You", 'Shawn Mendes', 23],
#  ["Even Though I'm Leaving", 'Luke Combs', 6],
#  ['Take What You Want', 'Post Malone;Ozzy Osbourne;Travis Scott', 5],
#  ["I Don't Know About You", 'Chris Lane', 14],
#  ['Time', 'NF', 12],
#  ['The Bones', 'Maren Morris', 3],
#  ['One Man Band', 'Old Dominion', 7],
#  ['Cash Shit', 'Megan Thee Stallion;DaBaby', 16],
#  ['Good Vibes', 'Chris Janson', 6],
#  ['The London', 'Young Thug;J. Cole;Travis Scott', 20],
#  ['Liar', 'Camila Cabello', 5],
#  ['Boyfriend', 'Ariana Grande;Social House', 10],
#  ['Living', 'Dierks Bentley', 11],
#  ["I'll Kill You", 'Summer Walker;Jhene Aiko', 1],
#  ['Enemies', 'Post Malone;DaBaby', 5],
#  ['Love You Too Late', 'Cole Swindell', 10],
#  ['What Happens In A Small Town', 'Brantley Gilbert;Lindsay Ell', 9],
#  ['Motivation', 'Normani', 8],
#  ['Hot Girl Bummer', 'blackbear', 4],
#  ['TOES', 'DaBaby;Lil Baby;Moneybagg Yo', 2],
#  ['Stretch You Out', 'Summer Walker;A Boogie Wit da Hoodie', 1],
#  ['Every Little Thing', 'Russell Dickerson', 6],
#  ['China', 'Anuel AA;Daddy Yankee;Karol G;Ozuna;J Balvin', 12],
#  ['Baby Sitter', 'DaBaby;Offset', 9],
#  ['Lalala', 'Y2K;bbno$', 15],
#  ['Body', 'Summer Walker', 1],
#  ['Writing On The Wall', 'French Montana;Post Malone;Cardi B;Rvssian', 2],
#  ["Don't Call Me Angel (Charlie's Angels)",
#   'Ariana Grande;Miley Cyrus;Lana Del Rey',
#   4],
#  ['Saint-Tropez', 'Post Malone', 5],
#  ['Tip Of My Tongue', 'Kenny Chesney', 13],
#  ['Otro Trago', 'Sech;Darell;Nicky Jam;Ozuna;Anuel AA', 18],
#  ['Drunk Dialing...LODT', 'Summer Walker', 1],
#  ['Over It', 'Summer Walker', 1],
#  ["Hollywood's Bleeding", 'Post Malone', 5],
#  ['Remember You Young', 'Thomas Rhett', 4],
#  ['Nice To Meet Ya', 'Niall Horan', 1],
#  ['F.N', 'Lil Tjay', 9],
#  ['Higher Love', 'Kygo X Whitney Houston', 5],
#  ['Wish Wish', 'DJ Khaled;Cardi B;21 Savage', 13],
#  ['Callaita', 'Bad Bunny;Tainy', 18],
#  ['Southbound', 'Carrie Underwood', 13],
#  ['Bad Bad Bad', 'Young Thug;Lil Baby', 8],
#  ['RAW SHIT', 'DaBaby;Migos', 2],
#  ['Leave Em Alone', 'Layton Greene;Lil Baby;City Girls;PnB Rock', 1],
#  ['Potential', 'Summer Walker', 1],
#  ['Right Back', 'Khalid;A Boogie Wit da Hoodie', 11],
#  ['Die For Me', 'Post Malone;Future;Halsey', 5],
#  ['Heartache Medication', 'Jon Pardi', 2],
#  ['Dance Monkey', 'Tones And I', 1],
#  ['POP STAR', 'DaBaby;Kevin Gates', 2],
#  ['Self Control', 'YoungBoy Never Broke Again', 5],
#  ['No Me Conoce', 'Jhay Cortez;J Balvin;Bad Bunny', 14],
#  ['Slow Dancing In The Dark', 'Joji', 2]]

# %%
# let's turn out list into a dataframe
billDF = pd.DataFrame(data = billList)
billDF.columns = ['Song Title','Artists','Weeks on Billboard']

billDF.head()
# Out:
#             Song Title                      Artists  Weeks on Billboard
# 0  HIGHEST IN THE ROOM                 Travis Scott                   1
# 1          Truth Hurts                        Lizzo                  23
# 2             Senorita  Shawn Mendes;Camila Cabello                  16
# 3         10,000 Hours       Dan;Shay;Justin Bieber                   1
# 4    Someone You Loved                Lewis Capaldi                  22

# %% [markdown]
# ## API #2: [Spotify for Developers](https://developer.spotify.com/documentation/web-api/)
# `pip install spotipy`<br>
# [spotipy documentation](https://spotipy.readthedocs.io/en/latest/)

# %%
# Libraries for working with spotify api
import spotipy as sy
from spotipy.oauth2 import SpotifyClientCredentials as sycred

# %%
# retrieve API credentials
with open('api_keys.json','r') as file:
    creds = json.load(file)

# create a variable that handles requests
handler = sycred(client_id = creds['spotify']['client_id'],
                 client_secret = creds['spotify']['client_secret'])

sp = sy.Spotify(client_credentials_manager = handler)

# %%
# add new columns to our top100 datafframe for the Spotify API
billDF = billDF.reindex(columns = ['Song Title','Artists','Weeks on Billboard',
                                   'Key','Mode','Acousticness','Danceability',
                                   'Energy','Instrumentalness','Liveness',
                                   'Loudness','Speechiness','Valence','Tempo',
                                  ])

billDF.head()
# Out:
#             Song Title                      Artists  Weeks on Billboard  Key  \
# 0  HIGHEST IN THE ROOM                 Travis Scott                   1  NaN
# 1          Truth Hurts                        Lizzo                  23  NaN
# 2             Senorita  Shawn Mendes;Camila Cabello                  16  NaN
# 3         10,000 Hours       Dan;Shay;Justin Bieber                   1  NaN
# 4    Someone You Loved                Lewis Capaldi                  22  NaN
#
#    Mode  Acousticness  Danceability  Energy  Instrumentalness  Liveness  \
# 0   NaN           NaN           NaN     NaN               NaN       NaN
# 1   NaN           NaN           NaN     NaN               NaN       NaN
# 2   NaN           NaN           NaN     NaN               NaN       NaN
# 3   NaN           NaN           NaN     NaN               NaN       NaN
# 4   NaN           NaN           NaN     NaN               NaN       NaN
#
#    Loudness  Speechiness  Valence  Tempo
# 0       NaN          NaN      NaN    NaN
# 1       NaN          NaN      NaN    NaN
# 2       NaN          NaN      NaN    NaN
# 3       NaN          NaN      NaN    NaN
# 4       NaN          NaN      NaN    NaN

# %%
# create a function to population the new columns in dataframe with the values
# from our Spotify API
def spSong(song_name):
    trackID = sp.search(song_name,type='track')['tracks']['items'][1]['uri']
    trackFeat = sp.audio_features(trackID)
    iSong = billDF.index[billDF['Song Title'] == song_name].tolist()[0]
    # Key
    billDF.at[iSong,'Key'] = trackFeat[0]['key']
    # Mode
    billDF.at[iSong,'Mode'] = trackFeat[0]['mode']
    # Acousticness
    billDF.at[iSong,'Acousticness'] = trackFeat[0]['acousticness']
    # Danceability
    billDF.at[iSong,'Danceability'] = trackFeat[0]['danceability']
    # Energy
    billDF.at[iSong,'Energy'] = trackFeat[0]['energy']
    # Instrumentalness
    billDF.at[iSong,'Instrumentalness'] = trackFeat[0]['instrumentalness']
    # Liveness
    billDF.at[iSong,'Liveness'] = trackFeat[0]['liveness']
    # Loudness
    billDF.at[iSong,'Loudness'] = trackFeat[0]['loudness']
    # Speechiness
    billDF.at[iSong,'Speechiness'] = trackFeat[0]['speechiness']
    # Valence
    billDF.at[iSong,'Valence'] = trackFeat[0]['valence']
    # Tempo
    billDF.at[iSong,'Tempo'] = trackFeat[0]['tempo']

# %%
# populate my dataframe
for i, song in billDF.iterrows():
    spSong(song[0])

# %%
# let's check it out
billDF.head()
# Out:
#             Song Title                      Artists  Weeks on Billboard   Key  \
# 0  HIGHEST IN THE ROOM                 Travis Scott                   1  10.0
# 1          Truth Hurts                        Lizzo                  23   4.0
# 2             Senorita  Shawn Mendes;Camila Cabello                  16   9.0
# 3         10,000 Hours       Dan;Shay;Justin Bieber                   1   5.0
# 4    Someone You Loved                Lewis Capaldi                  22   1.0
#
#    Mode  Acousticness  Danceability  Energy  Instrumentalness  Liveness  \
# 0   0.0        0.9390         0.818  0.0892             0.614    0.1140
# 1   0.0        0.1930         0.706  0.6280             0.000    0.1260
# 2   0.0        0.0392         0.759  0.5480             0.000    0.0828
# 3   0.0        0.2030         0.598  0.4050             0.000    0.3110
# 4   1.0        0.7510         0.501  0.4050             0.000    0.1050
#
#    Loudness  Speechiness  Valence    Tempo
# 0   -21.319       0.1570    0.414  113.931
# 1    -2.940       0.2010    0.380  158.036
# 2    -6.049       0.0290    0.749  116.967
# 3    -8.155       0.0464    0.244  122.144
# 4    -5.679       0.0319    0.446  109.891

# %% [markdown]
# ## API #3: [Genius API](https://docs.genius.com/)
# `pip install lyricsgenius`<br>
#
# [lyricsgenius documentation](https://github.com/johnwmillr/LyricsGenius)
# #### + Vadar Sentiment Analysis

# %%
# Libraries for working with genius api
import lyricsgenius as lg

# %%
# impliment credentials for accessing API
gpA = lg.Genius(creds['genius']['access_token'])

# create a function for requesting artists
def gpArtist(artist_name,song_amount):
    artist = gpA.search_artist(artist_name, max_songs = song_amount,
                                    sort = "title")
    return artist.songs

# create function for requesting songs
def gpSong(song_name,artist_name):
    song = gpA.search_song(song_name,artist_name)
    return song

# %%
# this line of code is here to make vader easier to use
analyzer = vsia()

# %%
# add new columns to our top100 datafframe for the Spotify API
billDF = billDF.reindex(columns = ['Song Title','Artists','Weeks on Billboard',
                                   'Key','Mode','Acousticness','Danceability',
                                   'Energy','Instrumentalness','Liveness',
                                   'Loudness','Speechiness','Valence','Tempo',
                                   'vNeg','vNeu','vPos','vCompound'
                                  ])

billDF.head()
# Out:
#             Song Title                      Artists  Weeks on Billboard   Key  \
# 0  HIGHEST IN THE ROOM                 Travis Scott                   1  10.0
# 1          Truth Hurts                        Lizzo                  23   4.0
# 2             Senorita  Shawn Mendes;Camila Cabello                  16   9.0
# 3         10,000 Hours       Dan;Shay;Justin Bieber                   1   5.0
# 4    Someone You Loved                Lewis Capaldi                  22   1.0
#
#    Mode  Acousticness  Danceability  Energy  Instrumentalness  Liveness  \
# 0   0.0        0.9390         0.818  0.0892             0.614    0.1140
# 1   0.0        0.1930         0.706  0.6280             0.000    0.1260
# 2   0.0        0.0392         0.759  0.5480             0.000    0.0828
# 3   0.0        0.2030         0.598  0.4050             0.000    0.3110
# 4   1.0        0.7510         0.501  0.4050             0.000    0.1050
#
#    Loudness  Speechiness  Valence    Tempo  vNeg  vNeu  vPos  vCompound
# 0   -21.319       0.1570    0.414  113.931   NaN   NaN   NaN        NaN
# 1    -2.940       0.2010    0.380  158.036   NaN   NaN   NaN        NaN
# 2    -6.049       0.0290    0.749  116.967   NaN   NaN   NaN        NaN
# 3    -8.155       0.0464    0.244  122.144   NaN   NaN   NaN        NaN
# 4    -5.679       0.0319    0.446  109.891   NaN   NaN   NaN        NaN

# %%
billDF.tail()
# Out:
#                   Song Title                         Artists  \
# 95              Dance Monkey                     Tones And I
# 96                  POP STAR              DaBaby;Kevin Gates
# 97              Self Control      YoungBoy Never Broke Again
# 98              No Me Conoce  Jhay Cortez;J Balvin;Bad Bunny
# 99  Slow Dancing In The Dark                            Joji
#
#     Weeks on Billboard   Key  Mode  Acousticness  Danceability  Energy  \
# 95                   1   9.0   1.0       0.00387         0.731   0.839
# 96                   2   9.0   0.0       0.03740         0.729   0.703
# 97                   5   8.0   1.0       0.76500         0.572   0.209
# 98                  14  10.0   0.0       0.14500         0.806   0.786
# 99                   2   5.0   0.0       0.00616         0.752   0.883
#
#     Instrumentalness  Liveness  Loudness  Speechiness  Valence    Tempo  vNeg  \
# 95          0.000024    0.2110    -4.509       0.0291    0.948  125.892   NaN
# 96          0.000189    0.0998    -6.771       0.1200    0.437  155.008   NaN
# 97          0.000000    0.3560   -10.413       0.0313    0.446   80.069   NaN
# 98          0.000000    0.0935    -3.831       0.0741    0.580   91.973   NaN
# 99          0.099800    0.1670    -4.450       0.0426    0.509  122.026   NaN
#
#     vNeu  vPos  vCompound
# 95   NaN   NaN        NaN
# 96   NaN   NaN        NaN
# 97   NaN   NaN        NaN
# 98   NaN   NaN        NaN
# 99   NaN   NaN        NaN

# %%
# use genius api to grab the lyrics for each song in the hot100 dataframe
for i, song in billDF.iterrows():
    song_name = song[0]
    song_lyrics = gpSong(song[0],song[1]).lyrics
    sentiment = analyzer.polarity_scores(song_lyrics)
    iSong = billDF.index[billDF['Song Title'] == song_name].tolist()[0]
    # Negative Vader Score
    billDF.at[iSong,'vNeg'] = sentiment['neg']
    # Neutral Vader Score
    billDF.at[iSong,'vNeu'] = sentiment['neu']
    # Positive Vader Score
    billDF.at[iSong,'vPos'] = sentiment['pos']
    # Compound Vader Score
    billDF.at[iSong,'vCompound'] = sentiment['compound']
# Out:
# Searching for "HIGHEST IN THE ROOM" by Travis Scott...
# Done.
# Searching for "Truth Hurts" by Lizzo...
# Done.
# Searching for "Senorita" by Shawn Mendes;Camila Cabello...
# Done.
# Searching for "10,000 Hours" by Dan;Shay;Justin Bieber...
# Done.
# Searching for "Someone You Loved" by Lewis Capaldi...
# Done.
# Searching for "Circles" by Post Malone...
# Done.
# Searching for "No Guidance" by Chris Brown;Drake...
# Done.
# Searching for "Ran$om" by Lil Tecca...
# Done.
# Searching for "Bad Guy" by Billie Eilish...
# Done.
# Searching for "Panini" by Lil Nas X...
# Done.
# Searching for "Bandit" by Juice WRLD;YoungBoy Never Broke Again...
# Done.
# Searching for "Goodbyes" by Post Malone;Young Thug...
# Done.
# Searching for "I Don't Care" by Ed Sheeran;Justin Bieber...
# Done.
# Searching for "Old Town Road" by Lil Nas X;Billy Ray Cyrus...
# Done.
# Searching for "Beautiful People" by Ed Sheeran;Khalid...
# Done.
# Searching for "Playing Games" by Summer Walker...
# Done.
# Searching for "Talk" by Khalid...
# Done.
# Searching for "Sunflower (Spider-Man: Into The Spider-Verse)" by Post Malone;Swae Lee...
# Done.
# Searching for "Sucker" by Jonas Brothers...
# Done.
# Searching for "Memories" by Maroon 5...
# Done.
# Searching for "Money In The Grave" by Drake;Rick Ross...
# Done.
# Searching for "Trampoline" by SHAED...
# Done.
# Searching for "Only Human" by Jonas Brothers...
# Done.
# Searching for "Good As Hell" by Lizzo...
# Done.
# Searching for "Suge" by DaBaby...
# Done.
# Searching for "How Do You Sleep?" by Sam Smith...
# Done.
# Searching for "On Chill" by Wale;Jeremih...
# Done.
# Searching for "You Need To Calm Down" by Taylor Swift...
# Done.
# Searching for "Baby" by Lil Baby;DaBaby...
# Done.
# Searching for "Ballin'" by Mustard;Roddy Ricch...
# Done.
# Searching for "Hot Girl Summer" by Megan Thee Stallion;Nicki Minaj;Ty Dolla $ign...
# Done.
# Searching for "INTRO" by DaBaby...
# Done.
# Searching for "Dancing With A Stranger" by Sam Smith;Normani...
# Done.
# Searching for "Lover" by Taylor Swift...
# Done.
# Searching for "My Type" by Saweetie...
# Done.
# Searching for "Prayed For You" by Matt Stell...
# Done.
# Searching for "223's" by YNW Melly;9lokknine...
# Done.
# Searching for "Hot" by Young Thug;Gunna...
# Done.
# Searching for "Wow." by Post Malone...
# Done.
# Searching for "Camelot" by NLE Choppa...
# Done.
# Searching for "BOP" by DaBaby...
# Done.
# Searching for "Come Thru" by Summer Walker;Usher...
# Done.
# Searching for "One Thing Right" by Marshmello;Kane Brown...
# Done.
# Searching for "Graveyard" by Halsey...
# Done.
# Searching for "The Git Up" by Blanco Brown...
# Done.
# Searching for "VIBEZ" by DaBaby...
# Done.
# Searching for "Heat" by Chris Brown;Gunna...
# Done.
# Searching for "If I Can't Have You" by Shawn Mendes...
# Done.
# Searching for "Even Though I'm Leaving" by Luke Combs...
# Done.
# Searching for "Take What You Want" by Post Malone;Ozzy Osbourne;Travis Scott...
# Done.
# Searching for "I Don't Know About You" by Chris Lane...
# Done.
# Searching for "Time" by NF...
# Done.
# Searching for "The Bones" by Maren Morris...
# Done.
# Searching for "One Man Band" by Old Dominion...
# Done.
# Searching for "Cash Shit" by Megan Thee Stallion;DaBaby...
# Done.
# Searching for "Good Vibes" by Chris Janson...
# Done.
# Searching for "The London" by Young Thug;J. Cole;Travis Scott...
# Done.
# Searching for "Liar" by Camila Cabello...
# Done.
# Searching for "Boyfriend" by Ariana Grande;Social House...
# Done.
# Searching for "Living" by Dierks Bentley...
# Done.
# Searching for "I'll Kill You" by Summer Walker;Jhene Aiko...
# Done.
# Searching for "Enemies" by Post Malone;DaBaby...
# Done.
# Searching for "Love You Too Late" by Cole Swindell...
# Done.
# Searching for "What Happens In A Small Town" by Brantley Gilbert;Lindsay Ell...
# Done.
# Searching for "Motivation" by Normani...
# Done.
# Searching for "Hot Girl Bummer" by blackbear...
# Done.
# Searching for "TOES" by DaBaby;Lil Baby;Moneybagg Yo...
# Done.
# Searching for "Stretch You Out" by Summer Walker;A Boogie Wit da Hoodie...
# Done.
# Searching for "Every Little Thing" by Russell Dickerson...
# Done.
# Searching for "China" by Anuel AA;Daddy Yankee;Karol G;Ozuna;J Balvin...
# Done.
# Searching for "Baby Sitter" by DaBaby;Offset...
# Done.
# Searching for "Lalala" by Y2K;bbno$...
# Done.
# Searching for "Body" by Summer Walker...
# Done.
# Searching for "Writing On The Wall" by French Montana;Post Malone;Cardi B;Rvssian...
# Done.
# Searching for "Don't Call Me Angel (Charlie's Angels)" by Ariana Grande;Miley Cyrus;Lana Del Rey...
# Done.
# Searching for "Saint-Tropez" by Post Malone...
# Done.
# Searching for "Tip Of My Tongue" by Kenny Chesney...
# Done.
# Searching for "Otro Trago" by Sech;Darell;Nicky Jam;Ozuna;Anuel AA...
# Done.
# Searching for "Drunk Dialing...LODT" by Summer Walker...
# Done.
# Searching for "Over It" by Summer Walker...
# Done.
# Searching for "Hollywood's Bleeding" by Post Malone...
# Done.
# Searching for "Remember You Young" by Thomas Rhett...
# Done.
# Searching for "Nice To Meet Ya" by Niall Horan...
# Done.
# Searching for "F.N" by Lil Tjay...
# Done.
# Searching for "Higher Love" by Kygo X Whitney Houston...
# Done.
# Searching for "Wish Wish" by DJ Khaled;Cardi B;21 Savage...
# Done.
# Searching for "Callaita" by Bad Bunny;Tainy...
# Done.
# Searching for "Southbound" by Carrie Underwood...
# Done.
# Searching for "Bad Bad Bad" by Young Thug;Lil Baby...
# Done.
# Searching for "RAW SHIT" by DaBaby;Migos...
# Done.
# Searching for "Leave Em Alone" by Layton Greene;Lil Baby;City Girls;PnB Rock...
# Done.
# Searching for "Potential" by Summer Walker...
# Done.
# Searching for "Right Back" by Khalid;A Boogie Wit da Hoodie...
# Done.
# Searching for "Die For Me" by Post Malone;Future;Halsey...
# Done.
# Searching for "Heartache Medication" by Jon Pardi...
# Done.
# Searching for "Dance Monkey" by Tones And I...
# Done.
# Searching for "POP STAR" by DaBaby;Kevin Gates...
# Done.
# Searching for "Self Control" by YoungBoy Never Broke Again...
# Done.
# Searching for "No Me Conoce" by Jhay Cortez;J Balvin;Bad Bunny...
# Done.
# Searching for "Slow Dancing In The Dark" by Joji...
# Done.

# %%
# let's check it out
billDF.head()
# Out:
#             Song Title                      Artists  Weeks on Billboard   Key  \
# 0  HIGHEST IN THE ROOM                 Travis Scott                   1  10.0
# 1          Truth Hurts                        Lizzo                  23   4.0
# 2             Senorita  Shawn Mendes;Camila Cabello                  16   9.0
# 3         10,000 Hours       Dan;Shay;Justin Bieber                   1   5.0
# 4    Someone You Loved                Lewis Capaldi                  22   1.0
#
#    Mode  Acousticness  Danceability  Energy  Instrumentalness  Liveness  \
# 0   0.0        0.9390         0.818  0.0892             0.614    0.1140
# 1   0.0        0.1930         0.706  0.6280             0.000    0.1260
# 2   0.0        0.0392         0.759  0.5480             0.000    0.0828
# 3   0.0        0.2030         0.598  0.4050             0.000    0.3110
# 4   1.0        0.7510         0.501  0.4050             0.000    0.1050
#
#    Loudness  Speechiness  Valence    Tempo   vNeg   vNeu   vPos  vCompound
# 0   -21.319       0.1570    0.414  113.931  0.052  0.839  0.109     0.9747
# 1    -2.940       0.2010    0.380  158.036  0.075  0.628  0.297     0.9994
# 2    -6.049       0.0290    0.749  116.967  0.024  0.712  0.265     0.9989
# 3    -8.155       0.0464    0.244  122.144  0.021  0.772  0.208     0.9978
# 4    -5.679       0.0319    0.446  109.891  0.076  0.787  0.138     0.9788

# %%
# export my dataframe to excel for visualization in Tableau
billDF.to_excel("API_Data.xlsx", sheet_name='API_Data')
